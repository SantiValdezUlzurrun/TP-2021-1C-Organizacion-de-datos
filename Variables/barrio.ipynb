# %%
# %run "../Secciones/feature_engineering.ipynb"

# %% [markdown]
# ### Barrio

# %%
#BARPLOT
plt.figure(figsize=(16, 12))

ax = sns.barplot(
    data=df,
    x='barrio',
     y='tiene_alto_valor_adquisitivo')

plt.ylabel("barrio")
plt.xlabel("Tiene alto valor adquisitivo")
plt.xticks(rotation=90)
plt.title('Relación entre los años estudiados y poder adquisitivo')
prom = df['tiene_alto_valor_adquisitivo'].mean()
plt.axhline(prom, color="darkred", label="Promedio de personas con alto VA")
plt.show()

# %%
df['barrio'].value_counts(normalize = True)
# Out:
# Palermo                0.913672
# Belgrano               0.019768
# San Isidro             0.006087
# Villa Urquiza          0.004212
# Recoleta               0.003720
# La Boca                0.003505
# Agronomia              0.003259
# Almagro                0.003074
# Balvanera              0.002921
# Puerto Madero          0.002767
# Caballito              0.002490
# Boedo                  0.002459
# Barracas               0.002306
# Chacarita              0.002244
# Coghland               0.002152
# Floresta               0.002060
# Constitucion           0.001968
# Colegiales             0.001906
# Flores                 0.001845
# Liniers                0.001814
# Monte Castro           0.001568
# Mataderos              0.001353
# Nueva Pompeya          0.001322
# Monserrat              0.001138
# nuñez                  0.001045
# Parque Chacabuco       0.000953
# Parque Avellaneda      0.000892
# Villa Luro             0.000892
# Parque Chas            0.000861
# La Paternal            0.000738
# Retiro                 0.000615
# Villa Soldati          0.000584
# Villa Devoto           0.000584
# Villa Real             0.000553
# San Telmo              0.000553
# Santa Rita             0.000492
# Villa General Mitre    0.000430
# Velez Sarsfield        0.000400
# Versalles              0.000400
# Villa Pueyrredon       0.000369
# Cilla Riachuelo        0.000031
# Name: barrio, dtype: float64

# %%
#BARPLOT
plt.figure(figsize=(16, 12))
df_comunas = df[['comuna', 'tiene_alto_valor_adquisitivo']].copy()
indices = df_comunas.groupby('comuna')['tiene_alto_valor_adquisitivo'].aggregate(lambda x: np.mean(x))

ax = sns.barplot(
    data=df,
    x='comuna',
    y='tiene_alto_valor_adquisitivo',
    order= indices.sort_values(ascending=False).index  )

plt.xlabel("comuna")
plt.ylabel("Tiene alto valor adquisitivo")
plt.title('Relación entre las comunas y poder adquisitivo')
prom = df['tiene_alto_valor_adquisitivo'].mean()
plt.axhline(prom, color="darkred", label="Promedio de personas con alto VA")
plt.show()

# %%
plt.figure(dpi = 200)

df_sin_palermo = df[df['barrio'] != 'Palermo']
ax = sns.countplot(x="comuna", hue="tiene_alto_valor_adquisitivo", data=df_sin_palermo)
plt.show()
